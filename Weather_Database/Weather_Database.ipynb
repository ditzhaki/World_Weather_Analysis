# %%
# Import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import requests
from config import weather_api_key

import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low = -90.0, high = 90.0, size = 2000)
lngs = np.random.uniform(low = -180.0, high = 180.0, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities

cities = []

# Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 758

# %%
# Starting URL for Weather Map API Call

url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&"

# %%
# Create an empty list to hold the weather data

city_data = []

# Print the beginning of the logging

print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    
    city_url = url + "appid=" + weather_api_key + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    
    record_count += 1

# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard
        city_to_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %h:%M:%S')
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descr})

# If an error is experienced, skip the city
    except BaseException as e:
        print("City not found. Skipping...")
        print(e)
        pass

# Indicate that Data Loading is complete
print("---------------------------")
print("Data Retrieval Complete    ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | benghazi
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | bloemhof
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | kasrawad
# Processing Record 10 of Set 1 | stoyba
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 1 | sibolga
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | yar-sale
# Processing Record 15 of Set 1 | cayenne
# Processing Record 16 of Set 1 | banda aceh
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | forrest city
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | westport
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | bambanglipuro
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | sicuani
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | kaoma
# Processing Record 38 of Set 1 | ormara
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | alice springs
# Processing Record 50 of Set 1 | kaitangata
# Processing Record 1 of Set 2 | margate
# Processing Record 2 of Set 2 | mawlaik
# Processing Record 3 of Set 2 | hunza
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | te anau
# Processing Record 7 of Set 2 | charlestown
# Processing Record 8 of Set 2 | marihatag
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | warmbad
# Processing Record 12 of Set 2 | cooma
# Processing Record 13 of Set 2 | seda
# Processing Record 14 of Set 2 | saint george
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | korhogo
# Processing Record 17 of Set 2 | kushiro
# Processing Record 18 of Set 2 | rocha
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | kingaroy
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | sioux lookout
# Processing Record 24 of Set 2 | taltal
# Processing Record 25 of Set 2 | chara
# Processing Record 26 of Set 2 | viedma
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | flinders
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | yangambi
# Processing Record 31 of Set 2 | bolshevik
# Processing Record 32 of Set 2 | prince rupert
# Processing Record 33 of Set 2 | ratnagiri
# Processing Record 34 of Set 2 | jardim
# Processing Record 35 of Set 2 | rorvik
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 2 | half moon bay
# Processing Record 38 of Set 2 | anadyr
# Processing Record 39 of Set 2 | tubruq
# City not found. Skipping...
# 'coord'
# Processing Record 40 of Set 2 | port hedland
# Processing Record 41 of Set 2 | rey bouba
# Processing Record 42 of Set 2 | isangel
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | pangai
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | kapit
# Processing Record 47 of Set 2 | cape town
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | itoman
# Processing Record 50 of Set 2 | kavaratti
# Processing Record 1 of Set 3 | houston
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | north bend
# Processing Record 6 of Set 3 | saryshagan
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 3 | puerto del rosario
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | tautira
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | noumea
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | lasa
# Processing Record 15 of Set 3 | vanimo
# Processing Record 16 of Set 3 | cockburn town
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | baykit
# Processing Record 19 of Set 3 | palabuhanratu
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 3 | nizwa
# Processing Record 21 of Set 3 | awjilah
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | kokoda
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | ilhabela
# Processing Record 26 of Set 3 | cochrane
# Processing Record 27 of Set 3 | santa maria
# Processing Record 28 of Set 3 | gondanglegi
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | booue
# Processing Record 31 of Set 3 | waipawa
# Processing Record 32 of Set 3 | quatre cocos
# Processing Record 33 of Set 3 | broome
# Processing Record 34 of Set 3 | dingzhou
# Processing Record 35 of Set 3 | bolungarvik
# City not found. Skipping...
# 'coord'
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 3 | bubaque
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | kez
# Processing Record 40 of Set 3 | yelizovo
# Processing Record 41 of Set 3 | campana
# Processing Record 42 of Set 3 | kilis
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# 'coord'
# Processing Record 44 of Set 3 | alta floresta
# Processing Record 45 of Set 3 | xianshuigu
# Processing Record 46 of Set 3 | jiroft
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 3 | chalon-sur-saone
# Processing Record 48 of Set 3 | khorixas
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 3 | bathsheba
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | parnamirim
# Processing Record 3 of Set 4 | namibe
# Processing Record 4 of Set 4 | bodden town
# Processing Record 5 of Set 4 | evensk
# Processing Record 6 of Set 4 | lososina
# Processing Record 7 of Set 4 | kadaya
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | tulun
# Processing Record 10 of Set 4 | cheuskiny
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 4 | guerrero negro
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | coahuayana
# Processing Record 14 of Set 4 | semme
# Processing Record 15 of Set 4 | taolanaro
# City not found. Skipping...
# 'coord'
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | bilibino
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | mastic beach
# Processing Record 20 of Set 4 | cururupu
# Processing Record 21 of Set 4 | charters towers
# Processing Record 22 of Set 4 | bad mergentheim
# Processing Record 23 of Set 4 | clyde river
# Processing Record 24 of Set 4 | namtsy
# Processing Record 25 of Set 4 | kodinsk
# Processing Record 26 of Set 4 | belmonte
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | marystown
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | cabra
# Processing Record 31 of Set 4 | nemuro
# Processing Record 32 of Set 4 | richards bay
# Processing Record 33 of Set 4 | buala
# Processing Record 34 of Set 4 | prieska
# Processing Record 35 of Set 4 | havre-saint-pierre
# Processing Record 36 of Set 4 | constitucion
# Processing Record 37 of Set 4 | adrar
# Processing Record 38 of Set 4 | tuy hoa
# Processing Record 39 of Set 4 | aksu
# Processing Record 40 of Set 4 | sosva
# Processing Record 41 of Set 4 | atar
# Processing Record 42 of Set 4 | puerto ayacucho
# Processing Record 43 of Set 4 | imbituba
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | arraial do cabo
# Processing Record 46 of Set 4 | nizhneyansk
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 4 | lao cai
# Processing Record 48 of Set 4 | pochutla
# Processing Record 49 of Set 4 | mentok
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 4 | diamantino
# Processing Record 1 of Set 5 | longyearbyen
# Processing Record 2 of Set 5 | moyale
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | muisne
# Processing Record 5 of Set 5 | moose factory
# Processing Record 6 of Set 5 | avera
# Processing Record 7 of Set 5 | sibu
# Processing Record 8 of Set 5 | tiarei
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | camana
# Processing Record 11 of Set 5 | palmer
# Processing Record 12 of Set 5 | caxito
# Processing Record 13 of Set 5 | sarankhola
# Processing Record 14 of Set 5 | homer
# Processing Record 15 of Set 5 | shilka
# Processing Record 16 of Set 5 | vagur
# Processing Record 17 of Set 5 | pozoblanco
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 5 | victor harbor
# Processing Record 20 of Set 5 | luoyang
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | bijar
# Processing Record 23 of Set 5 | batagay-alyta
# Processing Record 24 of Set 5 | rabo de peixe
# Processing Record 25 of Set 5 | atambua
# Processing Record 26 of Set 5 | alamosa
# Processing Record 27 of Set 5 | mahajanga
# Processing Record 28 of Set 5 | huilong
# Processing Record 29 of Set 5 | puerto carreno
# Processing Record 30 of Set 5 | karachi
# Processing Record 31 of Set 5 | tingrela
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 5 | luena
# Processing Record 33 of Set 5 | kasangulu
# Processing Record 34 of Set 5 | kieta
# Processing Record 35 of Set 5 | kropotkin
# Processing Record 36 of Set 5 | solnechnyy
# Processing Record 37 of Set 5 | dikson
# Processing Record 38 of Set 5 | kyshtovka
# Processing Record 39 of Set 5 | georgetown
# Processing Record 40 of Set 5 | lavrentiya
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | douglas
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | ritchie
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | samandag
# Processing Record 47 of Set 5 | tabou
# Processing Record 48 of Set 5 | la romana
# Processing Record 49 of Set 5 | sabzevar
# Processing Record 50 of Set 5 | humberto de campos
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | nizhnyaya poyma
# Processing Record 3 of Set 6 | dawlatabad
# Processing Record 4 of Set 6 | stephenville
# Processing Record 5 of Set 6 | azimur
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 6 | tumannyy
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 6 | wahran
# City not found. Skipping...
# 'coord'
# Processing Record 8 of Set 6 | morehead
# Processing Record 9 of Set 6 | acarau
# Processing Record 10 of Set 6 | bredasdorp
# Processing Record 11 of Set 6 | fort nelson
# Processing Record 12 of Set 6 | korla
# Processing Record 13 of Set 6 | kapchorwa
# Processing Record 14 of Set 6 | comodoro rivadavia
# Processing Record 15 of Set 6 | methoni
# Processing Record 16 of Set 6 | vaitupu
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 6 | champerico
# Processing Record 18 of Set 6 | zhezkazgan
# Processing Record 19 of Set 6 | port-cartier
# Processing Record 20 of Set 6 | finschhafen
# Processing Record 21 of Set 6 | herat
# Processing Record 22 of Set 6 | alofi
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 6 | beyneu
# Processing Record 25 of Set 6 | gat
# Processing Record 26 of Set 6 | salalah
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | beder
# Processing Record 29 of Set 6 | istok
# Processing Record 30 of Set 6 | fairbanks
# Processing Record 31 of Set 6 | ati
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | palampur
# Processing Record 34 of Set 6 | lavumisa
# Processing Record 35 of Set 6 | narrabri
# Processing Record 36 of Set 6 | ayame
# Processing Record 37 of Set 6 | santa rita do passa quatro
# Processing Record 38 of Set 6 | mount gambier
# Processing Record 39 of Set 6 | yithion
# City not found. Skipping...
# 'coord'
# Processing Record 40 of Set 6 | bedesa
# Processing Record 41 of Set 6 | college
# Processing Record 42 of Set 6 | sun valley
# Processing Record 43 of Set 6 | cassilandia
# Processing Record 44 of Set 6 | port lincoln
# Processing Record 45 of Set 6 | hualahuises
# Processing Record 46 of Set 6 | kalabo
# Processing Record 47 of Set 6 | solano
# Processing Record 48 of Set 6 | mankato
# Processing Record 49 of Set 6 | umzimvubu
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 6 | kismayo
# Processing Record 1 of Set 7 | carnot
# Processing Record 2 of Set 7 | dumas
# Processing Record 3 of Set 7 | kimbe
# Processing Record 4 of Set 7 | padang
# Processing Record 5 of Set 7 | tecoanapa
# Processing Record 6 of Set 7 | mitu
# Processing Record 7 of Set 7 | opuwo
# Processing Record 8 of Set 7 | taree
# Processing Record 9 of Set 7 | awbari
# Processing Record 10 of Set 7 | genhe
# Processing Record 11 of Set 7 | kanata
# Processing Record 12 of Set 7 | marathon
# Processing Record 13 of Set 7 | sao desiderio
# Processing Record 14 of Set 7 | souillac
# Processing Record 15 of Set 7 | cabo san lucas
# Processing Record 16 of Set 7 | znamenskoye
# Processing Record 17 of Set 7 | santa fe
# Processing Record 18 of Set 7 | calvinia
# Processing Record 19 of Set 7 | matagami
# Processing Record 20 of Set 7 | kouroussa
# Processing Record 21 of Set 7 | at-bashi
# Processing Record 22 of Set 7 | paso de los toros
# Processing Record 23 of Set 7 | jalu
# Processing Record 24 of Set 7 | ostrovnoy
# Processing Record 25 of Set 7 | abbeville
# Processing Record 26 of Set 7 | acapulco
# Processing Record 27 of Set 7 | nouadhibou
# Processing Record 28 of Set 7 | amapa
# Processing Record 29 of Set 7 | pangoa
# Processing Record 30 of Set 7 | fukue
# Processing Record 31 of Set 7 | gawler
# Processing Record 32 of Set 7 | thompson
# Processing Record 33 of Set 7 | la ronge
# Processing Record 34 of Set 7 | lorengau
# Processing Record 35 of Set 7 | jiddah
# City not found. Skipping...
# 'coord'
# Processing Record 36 of Set 7 | biloela
# Processing Record 37 of Set 7 | turka
# Processing Record 38 of Set 7 | kargopol
# Processing Record 39 of Set 7 | san antonio
# Processing Record 40 of Set 7 | rio gallegos
# Processing Record 41 of Set 7 | tadine
# Processing Record 42 of Set 7 | hami
# Processing Record 43 of Set 7 | urumqi
# Processing Record 44 of Set 7 | meyungs
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 7 | panixtlahuaca
# City not found. Skipping...
# 'coord'
# Processing Record 46 of Set 7 | coos bay
# Processing Record 47 of Set 7 | hithadhoo
# Processing Record 48 of Set 7 | alyangula
# Processing Record 49 of Set 7 | erenhot
# Processing Record 50 of Set 7 | gornopravdinsk
# Processing Record 1 of Set 8 | san quintin
# Processing Record 2 of Set 8 | srednekolymsk
# Processing Record 3 of Set 8 | muli
# Processing Record 4 of Set 8 | kailua
# Processing Record 5 of Set 8 | entre rios
# Processing Record 6 of Set 8 | kununurra
# Processing Record 7 of Set 8 | tezu
# Processing Record 8 of Set 8 | tarakan
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | kolosovka
# Processing Record 11 of Set 8 | porto novo
# Processing Record 12 of Set 8 | aflu
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 8 | sitka
# Processing Record 14 of Set 8 | trairi
# Processing Record 15 of Set 8 | kinel
# Processing Record 16 of Set 8 | shah alam
# Processing Record 17 of Set 8 | sangar
# Processing Record 18 of Set 8 | bac can
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 8 | lorient
# Processing Record 20 of Set 8 | urusha
# Processing Record 21 of Set 8 | amderma
# City not found. Skipping...
# 'coord'
# Processing Record 22 of Set 8 | tabas
# Processing Record 23 of Set 8 | crawfordsville
# Processing Record 24 of Set 8 | aswan
# Processing Record 25 of Set 8 | wilmington
# Processing Record 26 of Set 8 | batemans bay
# Processing Record 27 of Set 8 | tual
# Processing Record 28 of Set 8 | balkanabat
# Processing Record 29 of Set 8 | keti bandar
# Processing Record 30 of Set 8 | velikie luki
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 8 | mufumbwe
# Processing Record 32 of Set 8 | porto nacional
# Processing Record 33 of Set 8 | nome
# Processing Record 34 of Set 8 | sobolevo
# Processing Record 35 of Set 8 | udachnyy
# Processing Record 36 of Set 8 | kahului
# Processing Record 37 of Set 8 | oranjemund
# Processing Record 38 of Set 8 | lolua
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 8 | hastings
# Processing Record 40 of Set 8 | marsaxlokk
# Processing Record 41 of Set 8 | havre
# Processing Record 42 of Set 8 | ribeira grande
# Processing Record 43 of Set 8 | dalbandin
# Processing Record 44 of Set 8 | pangnirtung
# Processing Record 45 of Set 8 | whitehorse
# Processing Record 46 of Set 8 | hambantota
# Processing Record 47 of Set 8 | tura
# Processing Record 48 of Set 8 | hovd
# Processing Record 49 of Set 8 | mutsu
# Processing Record 50 of Set 8 | esmeraldas
# Processing Record 1 of Set 9 | malatya
# Processing Record 2 of Set 9 | cabo rojo
# Processing Record 3 of Set 9 | inuvik
# Processing Record 4 of Set 9 | seoul
# Processing Record 5 of Set 9 | maniitsoq
# Processing Record 6 of Set 9 | sirkali
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 9 | tyup
# Processing Record 8 of Set 9 | ndioum
# Processing Record 9 of Set 9 | hvide sande
# Processing Record 10 of Set 9 | ouargaye
# Processing Record 11 of Set 9 | gayny
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | north myrtle beach
# Processing Record 14 of Set 9 | ambikapur
# Processing Record 15 of Set 9 | kaeo
# Processing Record 16 of Set 9 | bandarbeyla
# Processing Record 17 of Set 9 | yulara
# Processing Record 18 of Set 9 | san cristobal
# Processing Record 19 of Set 9 | gizo
# Processing Record 20 of Set 9 | olinda
# Processing Record 21 of Set 9 | zeya
# Processing Record 22 of Set 9 | rasulnagar
# Processing Record 23 of Set 9 | ambilobe
# Processing Record 24 of Set 9 | los llanos de aridane
# Processing Record 25 of Set 9 | chandler
# Processing Record 26 of Set 9 | sao filipe
# Processing Record 27 of Set 9 | watertown
# Processing Record 28 of Set 9 | umm kaddadah
# Processing Record 29 of Set 9 | fairview
# Processing Record 30 of Set 9 | lokosovo
# Processing Record 31 of Set 9 | suzaka
# Processing Record 32 of Set 9 | karauzyak
# City not found. Skipping...
# 'coord'
# Processing Record 33 of Set 9 | terney
# Processing Record 34 of Set 9 | sakti
# Processing Record 35 of Set 9 | husavik
# Processing Record 36 of Set 9 | telimele
# Processing Record 37 of Set 9 | najran
# Processing Record 38 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 9 | talnakh
# Processing Record 40 of Set 9 | jiehu
# Processing Record 41 of Set 9 | gurupa
# Processing Record 42 of Set 9 | lagoa
# Processing Record 43 of Set 9 | ust-ordynskiy
# Processing Record 44 of Set 9 | marawi
# Processing Record 45 of Set 9 | pacific grove
# Processing Record 46 of Set 9 | xining
# Processing Record 47 of Set 9 | segezha
# Processing Record 48 of Set 9 | launceston
# Processing Record 49 of Set 9 | hammerfest
# Processing Record 50 of Set 9 | knysna
# Processing Record 1 of Set 10 | carutapera
# Processing Record 2 of Set 10 | chernyshevskiy
# Processing Record 3 of Set 10 | katsuura
# Processing Record 4 of Set 10 | labutta
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 10 | tsaratanana
# Processing Record 6 of Set 10 | muncar
# Processing Record 7 of Set 10 | leningradskiy
# Processing Record 8 of Set 10 | alvaraes
# Processing Record 9 of Set 10 | hare bay
# Processing Record 10 of Set 10 | churapcha
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | klaksvik
# Processing Record 13 of Set 10 | les cayes
# Processing Record 14 of Set 10 | manyana
# Processing Record 15 of Set 10 | vostok
# Processing Record 16 of Set 10 | zambezi
# Processing Record 17 of Set 10 | amot
# Processing Record 18 of Set 10 | dingle
# Processing Record 19 of Set 10 | san ignacio
# Processing Record 20 of Set 10 | rawson
# Processing Record 21 of Set 10 | mantua
# Processing Record 22 of Set 10 | tuymazy
# Processing Record 23 of Set 10 | cap malheureux
# Processing Record 24 of Set 10 | forest grove
# Processing Record 25 of Set 10 | bosaso
# Processing Record 26 of Set 10 | nabire
# Processing Record 27 of Set 10 | dunedin
# Processing Record 28 of Set 10 | faya
# Processing Record 29 of Set 10 | la orilla
# Processing Record 30 of Set 10 | saint anthony
# Processing Record 31 of Set 10 | beloomut
# Processing Record 32 of Set 10 | labuhan
# Processing Record 33 of Set 10 | poltavka
# Processing Record 34 of Set 10 | dwarka
# Processing Record 35 of Set 10 | poum
# Processing Record 36 of Set 10 | luderitz
# Processing Record 37 of Set 10 | morros
# Processing Record 38 of Set 10 | naliya
# Processing Record 39 of Set 10 | chupa
# Processing Record 40 of Set 10 | lata
# Processing Record 41 of Set 10 | mehamn
# Processing Record 42 of Set 10 | talcahuano
# Processing Record 43 of Set 10 | general roca
# Processing Record 44 of Set 10 | poshekhonye
# Processing Record 45 of Set 10 | tessalit
# Processing Record 46 of Set 10 | esmeralda
# Processing Record 47 of Set 10 | kargasok
# Processing Record 48 of Set 10 | cap-aux-meules
# Processing Record 49 of Set 10 | bara
# Processing Record 50 of Set 10 | paamiut
# Processing Record 1 of Set 11 | zubtsov
# Processing Record 2 of Set 11 | zhigansk
# Processing Record 3 of Set 11 | singapore
# Processing Record 4 of Set 11 | oranjestad
# Processing Record 5 of Set 11 | sentyabrskiy
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 11 | banikoara
# Processing Record 7 of Set 11 | karratha
# Processing Record 8 of Set 11 | bursa
# Processing Record 9 of Set 11 | harper
# Processing Record 10 of Set 11 | krasnoselkup
# Processing Record 11 of Set 11 | nakamura
# Processing Record 12 of Set 11 | yeppoon
# Processing Record 13 of Set 11 | burica
# City not found. Skipping...
# 'coord'
# Processing Record 14 of Set 11 | parkes
# Processing Record 15 of Set 11 | giyon
# Processing Record 16 of Set 11 | beloha
# Processing Record 17 of Set 11 | chiliile
# Processing Record 18 of Set 11 | lundazi
# Processing Record 19 of Set 11 | strelka
# Processing Record 20 of Set 11 | ozinki
# Processing Record 21 of Set 11 | beringovskiy
# Processing Record 22 of Set 11 | novikovo
# Processing Record 23 of Set 11 | marzuq
# Processing Record 24 of Set 11 | padilla
# Processing Record 25 of Set 11 | agar
# Processing Record 26 of Set 11 | moerai
# Processing Record 27 of Set 11 | north platte
# Processing Record 28 of Set 11 | cholan
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 11 | trelew
# Processing Record 30 of Set 11 | anandnagar
# Processing Record 31 of Set 11 | jabiru
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 11 | samarai
# Processing Record 33 of Set 11 | uenohara
# Processing Record 34 of Set 11 | monrovia
# Processing Record 35 of Set 11 | svetlogorsk
# Processing Record 36 of Set 11 | meulaboh
# Processing Record 37 of Set 11 | petatlan
# Processing Record 38 of Set 11 | lamu
# Processing Record 39 of Set 11 | saint-francois
# Processing Record 40 of Set 11 | nyekladhaza
# Processing Record 41 of Set 11 | tazovskiy
# Processing Record 42 of Set 11 | omvriaki
# Processing Record 43 of Set 11 | pareora
# Processing Record 44 of Set 11 | tuatapere
# Processing Record 45 of Set 11 | praya
# Processing Record 46 of Set 11 | siverek
# Processing Record 47 of Set 11 | mount isa
# Processing Record 48 of Set 11 | pisco
# Processing Record 49 of Set 11 | kemi
# Processing Record 50 of Set 11 | aviles
# Processing Record 1 of Set 12 | nuuk
# Processing Record 2 of Set 12 | mattru
# Processing Record 3 of Set 12 | tarauaca
# Processing Record 4 of Set 12 | saint-georges
# Processing Record 5 of Set 12 | tayu
# Processing Record 6 of Set 12 | lovington
# Processing Record 7 of Set 12 | griffith
# Processing Record 8 of Set 12 | aquidauana
# Processing Record 9 of Set 12 | waingapu
# Processing Record 10 of Set 12 | pontian kecil
# Processing Record 11 of Set 12 | miri
# Processing Record 12 of Set 12 | balakhninskiy
# Processing Record 13 of Set 12 | vila franca do campo
# Processing Record 14 of Set 12 | mogadishu
# Processing Record 15 of Set 12 | china
# Processing Record 16 of Set 12 | gurgan
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 12 | nsanje
# Processing Record 18 of Set 12 | allende
# Processing Record 19 of Set 12 | skjervoy
# Processing Record 20 of Set 12 | kendari
# Processing Record 21 of Set 12 | arvin
# Processing Record 22 of Set 12 | boa vista
# Processing Record 23 of Set 12 | ha giang
# Processing Record 24 of Set 12 | dawson creek
# Processing Record 25 of Set 12 | aykhal
# Processing Record 26 of Set 12 | sant julia de loria
# Processing Record 27 of Set 12 | drumheller
# Processing Record 28 of Set 12 | ossora
# Processing Record 29 of Set 12 | shenkursk
# Processing Record 30 of Set 12 | haapiti
# Processing Record 31 of Set 12 | trincomalee
# Processing Record 32 of Set 12 | hamilton
# Processing Record 33 of Set 12 | vilhena
# Processing Record 34 of Set 12 | rundu
# Processing Record 35 of Set 12 | port augusta
# Processing Record 36 of Set 12 | lushunkou
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 12 | shuangyang
# Processing Record 38 of Set 12 | koumac
# Processing Record 39 of Set 12 | freeport
# Processing Record 40 of Set 12 | kenai
# Processing Record 41 of Set 12 | muros
# Processing Record 42 of Set 12 | tiksi
# Processing Record 43 of Set 12 | atikokan
# Processing Record 44 of Set 12 | sao joao da barra
# Processing Record 45 of Set 12 | kroya
# Processing Record 46 of Set 12 | wanaka
# Processing Record 47 of Set 12 | santa rosa
# Processing Record 48 of Set 12 | kayerkan
# Processing Record 49 of Set 12 | vrangel
# Processing Record 50 of Set 12 | kamenka
# Processing Record 1 of Set 13 | mnogovershinnyy
# Processing Record 2 of Set 13 | eldikan
# City not found. Skipping...
# 'coord'
# Processing Record 3 of Set 13 | saint-pascal
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 13 | hirado
# Processing Record 5 of Set 13 | ishigaki
# Processing Record 6 of Set 13 | bandar maharani
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 13 | namatanai
# Processing Record 8 of Set 13 | bure
# Processing Record 9 of Set 13 | khilok
# Processing Record 10 of Set 13 | dakar
# Processing Record 11 of Set 13 | desaguadero
# Processing Record 12 of Set 13 | ampanihy
# Processing Record 13 of Set 13 | zyryanovsk
# Processing Record 14 of Set 13 | yizheng
# Processing Record 15 of Set 13 | callaguip
# Processing Record 16 of Set 13 | sao raimundo nonato
# Processing Record 17 of Set 13 | marcona
# City not found. Skipping...
# 'coord'
# Processing Record 18 of Set 13 | bydgoszcz
# Processing Record 19 of Set 13 | ahuimanu
# Processing Record 20 of Set 13 | stokmarknes
# Processing Record 21 of Set 13 | hirara
# Processing Record 22 of Set 13 | slave lake
# Processing Record 23 of Set 13 | teahupoo
# Processing Record 24 of Set 13 | narimanov
# Processing Record 25 of Set 13 | burnie
# Processing Record 26 of Set 13 | warqla
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 13 | honiara
# Processing Record 29 of Set 13 | laguna
# Processing Record 30 of Set 13 | kibala
# Processing Record 31 of Set 13 | todos santos
# Processing Record 32 of Set 13 | oytal
# Processing Record 33 of Set 13 | abu samrah
# Processing Record 34 of Set 13 | kurilsk
# Processing Record 35 of Set 13 | maine-soroa
# Processing Record 36 of Set 13 | kholmogory
# Processing Record 37 of Set 13 | pimenta bueno
# Processing Record 38 of Set 13 | great bend
# Processing Record 39 of Set 13 | bayir
# Processing Record 40 of Set 13 | rafraf
# Processing Record 41 of Set 13 | duncan
# Processing Record 42 of Set 13 | xuddur
# Processing Record 43 of Set 13 | babanusah
# City not found. Skipping...
# 'coord'
# Processing Record 44 of Set 13 | toungoo
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 13 | dentsville
# Processing Record 46 of Set 13 | kholodnyy
# Processing Record 47 of Set 13 | svetlyy
# Processing Record 48 of Set 13 | cape coast
# Processing Record 49 of Set 13 | mergui
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 13 | vallenar
# Processing Record 1 of Set 14 | bud
# Processing Record 2 of Set 14 | sakaiminato
# Processing Record 3 of Set 14 | buarcos
# Processing Record 4 of Set 14 | rong kwang
# Processing Record 5 of Set 14 | erzurum
# Processing Record 6 of Set 14 | colac
# Processing Record 7 of Set 14 | san matias
# Processing Record 8 of Set 14 | aneho
# Processing Record 9 of Set 14 | saint-joseph
# Processing Record 10 of Set 14 | ibra
# Processing Record 11 of Set 14 | abu zabad
# Processing Record 12 of Set 14 | palu
# Processing Record 13 of Set 14 | prince albert
# Processing Record 14 of Set 14 | pomabamba
# Processing Record 15 of Set 14 | pasighat
# Processing Record 16 of Set 14 | baker city
# Processing Record 17 of Set 14 | arrecife
# Processing Record 18 of Set 14 | bom sucesso
# Processing Record 19 of Set 14 | ketchikan
# Processing Record 20 of Set 14 | addis abeba
# Processing Record 21 of Set 14 | imeni poliny osipenko
# Processing Record 22 of Set 14 | nan
# Processing Record 23 of Set 14 | notre-dame-de-gravenchon
# Processing Record 24 of Set 14 | felidhoo
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 14 | zarnesti
# Processing Record 26 of Set 14 | qui nhon
# Processing Record 27 of Set 14 | mujiayingzi
# Processing Record 28 of Set 14 | srednebelaya
# Processing Record 29 of Set 14 | punta alta
# Processing Record 30 of Set 14 | rio grande
# Processing Record 31 of Set 14 | virginia beach
# Processing Record 32 of Set 14 | qandala
# Processing Record 33 of Set 14 | vicuna
# Processing Record 34 of Set 14 | semey
# Processing Record 35 of Set 14 | chapais
# Processing Record 36 of Set 14 | careiro da varzea
# Processing Record 37 of Set 14 | bela
# Processing Record 38 of Set 14 | lubliniec
# Processing Record 39 of Set 14 | dharmavaram
# Processing Record 40 of Set 14 | komsomolskiy
# Processing Record 41 of Set 14 | goderich
# Processing Record 42 of Set 14 | santa cruz
# Processing Record 43 of Set 14 | touros
# Processing Record 44 of Set 14 | tomatlan
# Processing Record 45 of Set 14 | berlevag
# Processing Record 46 of Set 14 | akyab
# Processing Record 47 of Set 14 | russell
# Processing Record 48 of Set 14 | auki
# Processing Record 49 of Set 14 | bukama
# Processing Record 50 of Set 14 | matara
# Processing Record 1 of Set 15 | lancaster
# Processing Record 2 of Set 15 | ciudad bolivar
# Processing Record 3 of Set 15 | pathein
# Processing Record 4 of Set 15 | rjukan
# Processing Record 5 of Set 15 | shenjiamen
# Processing Record 6 of Set 15 | buraydah
# Processing Record 7 of Set 15 | aklavik
# Processing Record 8 of Set 15 | wajima
# Processing Record 9 of Set 15 | tanshui
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 15 | dayong
# Processing Record 11 of Set 15 | tilichiki
# Processing Record 12 of Set 15 | dzhusaly
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 15 | dali
# Processing Record 14 of Set 15 | omboue
# Processing Record 15 of Set 15 | liverpool
# Processing Record 16 of Set 15 | danilovka
# Processing Record 17 of Set 15 | tagusao
# Processing Record 18 of Set 15 | bontang
# Processing Record 19 of Set 15 | elayirampannai
# Processing Record 20 of Set 15 | mashhad
# Processing Record 21 of Set 15 | anloga
# Processing Record 22 of Set 15 | almaznyy
# Processing Record 23 of Set 15 | camacha
# Processing Record 24 of Set 15 | hervey bay
# Processing Record 25 of Set 15 | harihar
# Processing Record 26 of Set 15 | havoysund
# Processing Record 27 of Set 15 | paita
# Processing Record 28 of Set 15 | qaqortoq
# Processing Record 29 of Set 15 | dongying
# Processing Record 30 of Set 15 | chiang klang
# Processing Record 31 of Set 15 | kirakira
# Processing Record 32 of Set 15 | bilma
# Processing Record 33 of Set 15 | moosomin
# Processing Record 34 of Set 15 | duldurga
# Processing Record 35 of Set 15 | itarema
# Processing Record 36 of Set 15 | edson
# Processing Record 37 of Set 15 | kirovskiy
# Processing Record 38 of Set 15 | tocopilla
# Processing Record 39 of Set 15 | cordoba
# Processing Record 40 of Set 15 | sibiti
# Processing Record 41 of Set 15 | borogontsy
# Processing Record 42 of Set 15 | roald
# Processing Record 43 of Set 15 | velikiy novgorod
# Processing Record 44 of Set 15 | ishikari
# Processing Record 45 of Set 15 | kasongo-lunda
# Processing Record 46 of Set 15 | kamaishi
# Processing Record 47 of Set 15 | biak
# Processing Record 48 of Set 15 | senanga
# Processing Record 49 of Set 15 | iroquois falls
# Processing Record 50 of Set 15 | pafos
# Processing Record 1 of Set 16 | plettenberg bay
# Processing Record 2 of Set 16 | vytegra
# Processing Record 3 of Set 16 | chissamba
# Processing Record 4 of Set 16 | grand river south east
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 16 | chumikan
# Processing Record 6 of Set 16 | neyvo-shaytanskiy
# Processing Record 7 of Set 16 | potiskum
# Processing Record 8 of Set 16 | strezhevoy
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Benghazi      LY  32.1167   20.0667     65.03        66           0
# 1  Severo-Kurilsk      RU  50.6789  156.1250     43.57        86         100
# 2        Bloemhof      ZA -27.6469   25.6070     49.24        80          96
# 3      Codrington      AU -38.2667  141.9667     51.98        73           7
# 4  Port Elizabeth      ZA -33.9180   25.5701     56.32        99         100
# 5    Punta Arenas      CL -53.1500  -70.9167     42.91        93         100
# 6            Hilo      US  19.7297 -155.0900     89.28        77          75
# 7     Port Alfred      ZA -33.5906   26.8910     61.74        68         100
# 8        Kasrawad      IN  22.1333   75.6000     83.91        58           0
# 9         Sibolga      ID   1.7427   98.7792     77.40        88          81
#
#    Wind Speed      Description
# 0       10.20        clear sky
# 1       10.67  overcast clouds
# 2       10.51       light rain
# 3        7.38        clear sky
# 4        6.91       light rain
# 5        6.91  overcast clouds
# 6       13.80    broken clouds
# 7        3.80  overcast clouds
# 8       18.48        clear sky
# 9        2.48    broken clouds

# %%
# Create the output file

output_data_file = "WeatherPy_Database.csv"

# Export the city_data into a csv

city_data_df.to_csv(output_data_file, index_label = "City_ID")
